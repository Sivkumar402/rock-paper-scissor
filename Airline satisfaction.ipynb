# %%
import pandas as pd
df = pd.read_csv('file:///C:/Users/siva/Desktop/train.csv')

# %%
df.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# ...

# %%
df.tail()
# Out:
#         Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 103899      103899  94171  Female  disloyal Customer   23  Business travel
# 103900      103900  73097    Male     Loyal Customer   49  Business travel
# 103901      103901  68825    Male  disloyal Customer   30  Business travel
# 103902      103902  54173  Female  disloyal Customer   22  Business travel
# 103903      103903  62567    Male     Loyal Customer   27  Business travel
#
#            Class  Flight Distance  Inflight wifi service  \
# 103899       Eco              192                      2
# 103900  Business             2347                      4
# 103901  Business             1995                      1
# 103902       Eco             1000                      1
# 103903  Business             1723                      1
#
#         Departure/Arrival time convenient  ...  Inflight entertainment  \
# 103899                                  1  ...                       2
# ...

# %%
df.shape
# Out:
# (103904, 25)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                             0
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0             id            Age  Flight Distance  \
# count  103904.000000  103904.000000  103904.000000    103904.000000
# mean    51951.500000   64924.210502      39.379706      1189.448375
# std     29994.645522   37463.812252      15.114964       997.147281
# min         0.000000       1.000000       7.000000        31.000000
# 25%     25975.750000   32533.750000      27.000000       414.000000
# 50%     51951.500000   64856.500000      40.000000       843.000000
# 75%     77927.250000   97368.250000      51.000000      1743.000000
# max    103903.000000  129880.000000      85.000000      4983.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count          103904.000000                      103904.000000
# mean                2.729683                           3.060296
# std                 1.327829                           1.525075
# min                 0.000000                           0.000000
# ...

# %%
mean_value = df['Arrival Delay in Minutes'].mean()

# %%
df['Arrival Delay in Minutes'].fillna(mean_value, inplace=True)
# Out:
# C:\Users\siva\AppData\Local\Temp\ipykernel_19400\2416455820.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Arrival Delay in Minutes'].fillna(mean_value, inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                           0
# id                                   0
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# ...

# %% [markdown]
# Box Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
columns_to_plot = ['Departure/Arrival time convenient', 'On-board service', 'Leg room service', 'Cleanliness']
melted_data = df[columns_to_plot].melt(var_name='Columns', value_name='Values')
plt.figure(figsize=(12, 6))
sns.boxplot(x='Columns', y='Values', data=melted_data)
plt.title('Boxplot')
plt.xlabel('Columns')
plt.ylabel('Values')
plt.show()

# %% [markdown]
# Bar Plot

# %%
sns.barplot(df["satisfaction"].value_counts())
plt.title('Satisfaction of customer')
# Out:
# Text(0.5, 1.0, 'Satisfaction of customer')

# %% [markdown]
# Scatter Plot

# %%
import matplotlib.pyplot as plt 

plt.figure(figsize=(10, 6))
plt.scatter(df['Age'], df['Flight Distance'], color='red')

plt.title('Scatter Plot of Flight Distance vs Age')
plt.xlabel('Age ')  
plt.ylabel('Flight Distance ')  
plt.show()

# %% [markdown]
# Hexbin plot

# %%
import matplotlib.pyplot as plt
x=df['Age']
y=df["Cleanliness"]
hb = plt.hexbin(x, y, gridsize=50, cmap='Blues')
plt.show()

# %%
df.columns.to_list()
# Out:
# ['Unnamed: 0',
#  'id',
#  'Gender',
#  'Customer Type',
#  'Age',
#  'Type of Travel',
#  'Class',
#  'Flight Distance',
#  'Inflight wifi service',
#  'Departure/Arrival time convenient',
#  'Ease of Online booking',
#  'Gate location',
#  'Food and drink',
#  'Online boarding',
#  'Seat comfort',
#  'Inflight entertainment',
#  'On-board service',
#  'Leg room service',
#  'Baggage handling',
#  'Checkin service',
#  'Inflight service',
#  'Cleanliness',
#  'Departure Delay in Minutes',
#  'Arrival Delay in Minutes',
#  'satisfaction']

# %%
df
# Out:
#         Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0                0   70172    Male     Loyal Customer   13  Personal Travel
# 1                1    5047    Male  disloyal Customer   25  Business travel
# 2                2  110028  Female     Loyal Customer   26  Business travel
# 3                3   24026  Female     Loyal Customer   25  Business travel
# 4                4  119299    Male     Loyal Customer   61  Business travel
# ...            ...     ...     ...                ...  ...              ...
# 103899      103899   94171  Female  disloyal Customer   23  Business travel
# 103900      103900   73097    Male     Loyal Customer   49  Business travel
# 103901      103901   68825    Male  disloyal Customer   30  Business travel
# 103902      103902   54173  Female  disloyal Customer   22  Business travel
# 103903      103903   62567    Male     Loyal Customer   27  Business travel
#
# ...

# %%
df= df[[
    'Unnamed: 0',
 'id',
#'Gender',
# 'Customer Type',
 'Age',
 #'Type of Travel',
 #'Class',
 'Flight Distance',
 'Inflight wifi service',
 'Departure/Arrival time convenient',
 'Ease of Online booking',
 'Gate location',
 'Food and drink',
 'Online boarding',
 'Seat comfort',
 'Inflight entertainment',
 'On-board service',
 'Leg room service',
 'Baggage handling',
 'Checkin service',
 'Inflight service',
 'Cleanliness',
 'Departure Delay in Minutes',
 'Arrival Delay in Minutes',
 #'satisfaction'
]]

# %%
x= df.corr()

# %%
df.dtypes
# Out:
# Unnamed: 0                             int64
# id                                     int64
# Gender                                object
# Customer Type                         object
# Age                                    int64
# Type of Travel                        object
# Class                                 object
# Flight Distance                        int64
# Inflight wifi service                  int64
# Departure/Arrival time convenient      int64
# Ease of Online booking                 int64
# Gate location                          int64
# Food and drink                         int64
# Online boarding                        int64
# Seat comfort                           int64
# Inflight entertainment                 int64
# On-board service                       int64
# Leg room service                       int64
# Baggage handling                       int64
# Checkin service                        int64
# Inflight service                       int64
# ...

# %% [markdown]
# Heat Map

# %%
sns.heatmap(x, annot=True, cmap='viridis')
plt.title('Heatmap')
plt.show()

# %% [markdown]
# Scatter Plot

# %%
import matplotlib.pyplot as plt 

plt.figure(figsize=(10, 6))
plt.scatter(df['Flight Distance'], df['Arrival Delay in Minutes'], color='blue')

plt.title('Scatter Plot of Flight Distance vs Delay')
plt.xlabel('Flight Distance')  
plt.ylabel('Arrival Delay in Minutes')  
plt.show()

# %% [markdown]
# 1. Are most of the customers satisfied with Airline services? - No
# 2. From which range the customers travel least - from 4000 to 5000 KM
# 3. Are cutomers happy with the cleanliness of flight? - Yes most of the customers (4 Rating) are satsisfied with Cleanliness of flight
# 4. Does delay in departure affect on the delay in arrival time ? Yes
# 5. Which flight distance range has the least Flight arrival delay ? 4000 to 50000 KM
